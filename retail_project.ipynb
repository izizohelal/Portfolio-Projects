# %% [markdown]
# ## the Sparks Foundation - Data Science & Business Analytics Internship
# ## Task 3: Perform 'Exploratory Data Analysis' on dataset 'SampleSuperStore'
# ### in this task we will try to find the weak areas where we can work on these to make more profits, steps to be followed : Importing the libraries Reading the dataset Data Preprocessing EDA Data Visualization
#
# ## Author - Moataz Helal

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Reading the dataset

# %%
df = pd.read_csv(r"D:\retail_project\SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # data processing

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df = df[['Ship Mode','Segment','City', 'State','Region',
        'Category', 'Sub-Category','Sales',
       'Quantity', 'Discount', 'Profit']]
df.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
df.describe().round(2)
# Out:
#           Sales  Quantity  Discount   Profit
# count   9994.00   9994.00   9994.00  9994.00
# mean     229.86      3.79      0.16    28.66
# std      623.25      2.23      0.21   234.26
# min        0.44      1.00      0.00 -6599.98
# 25%       17.28      2.00      0.00     1.73
# 50%       54.49      3.00      0.20     8.67
# 75%      209.94      5.00      0.20    29.36
# max    22638.48     14.00      0.80  8399.98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   City          9994 non-null   object
#  3   State         9994 non-null   object
#  4   Region        9994 non-null   object
#  5   Category      9994 non-null   object
#  6   Sub-Category  9994 non-null   object
#  7   Sales         9994 non-null   float64
#  8   Quantity      9994 non-null   int64
#  9   Discount      9994 non-null   float64
#  10  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 859.0+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 50

# %%
df[df.duplicated]
# Out:
#            Ship Mode      Segment           City         State   Region  \
# 950   Standard Class  Home Office   Philadelphia  Pennsylvania     East
# 1878  Standard Class     Consumer    Los Angeles    California     West
# 2979  Standard Class     Consumer   Philadelphia  Pennsylvania     East
# 3033  Standard Class  Home Office   Philadelphia  Pennsylvania     East
# 3406  Standard Class  Home Office       Columbus          Ohio     East
# 3564     First Class     Consumer    Los Angeles    California     West
# 3670  Standard Class     Consumer          Salem        Oregon     West
# 4117  Standard Class     Consumer    Los Angeles    California     West
# 4152  Standard Class     Consumer   Philadelphia  Pennsylvania     East
# 4311  Standard Class     Consumer    Los Angeles    California     West
# 4449  Standard Class     Consumer    Los Angeles    California     West
# 4485  Standard Class     Consumer    Los Angeles    California     West
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
segment_distribution = df['Segment'].value_counts()
segment_distribution
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.barplot(x = segment_distribution.index,y= segment_distribution);

# %%
correlations = df[['Sales','Quantity','Discount','Profit']].corr().round(2)
correlations
# Out:
#           Sales  Quantity  Discount  Profit
# Sales      1.00      0.20     -0.03    0.48
# Quantity   0.20      1.00      0.01    0.07
# Discount  -0.03      0.01      1.00   -0.22
# Profit     0.48      0.07     -0.22    1.00

# %%
sns.heatmap(data=correlations,annot=True);

# %% [markdown]
# ## Observation)1
# ## there's a strong positive correlation between Sales and profit for sure
# ## there's a strong negative correlation between Sales,profit and discount we will focus on this corr as it affects alot sales and profits

# %%
#identifying which state is selling most
plt.figure(figsize=(20,10))
sns.barplot(y=df.State,x=df.Sales,palette='Blues_d');

# %% [markdown]
# ## Observation)2
# ## vermont leading the way for cities with most sales

# %%
#identifying which region is selling most
plt.figure(figsize=(20,10))
sns.barplot(x=df.Region,y=df.Sales);

# %% [markdown]
# ## Observation)3
# ## south on top not too far from east and west in sales
# ## central is down there as the least region for sales

# %%
#despite most sales comes from south but the most profitable region is "west"
plt.figure(figsize=(15,8))
sns.barplot(x=df.Region,y=df.Profit,palette='Blues');

# %% [markdown]
# ## Observation)4
# ## west region is up there for profits
# ## central region is down there as the least profitable region

# %%
#sales vs profit per category 
df.groupby('Category')[['Sales','Profit']].sum().plot.bar();

# %% [markdown]
# ## Observation)5
# ## tech is up for sales and profit as well for +800k sales and for +145k profit

# %%
# avg sales and profit for every category 
df.groupby('Category')[['Sales','Profit']].mean().plot.bar();

# %% [markdown]
# ## Observation
# ## tech is up for avg sales and profit as well for +400 sales and for +70 profit

# %%
cat_sales = df.groupby('Segment')['Sales'].sum()
cat_profit = df.groupby('Segment')['Profit'].sum()

# %%
cat_sales.plot(kind='bar',legend=True)
cat_profit.plot(kind='bar',color='crimson',legend=True)
plt.show()

# %% [markdown]
# # Observation)6
# # consumer is up for sales and profit as well

# %%
df.groupby('Ship Mode')[['Sales','Profit']].sum().plot.bar();

# %% [markdown]
# ## Observation)7
# ## standard class shipmode is up for sales and profits
# ## we have to work on another plan for same day and first class as they sell less by far

# %%
df.groupby('Region')[['Sales','Profit']].sum().plot.bar();

# %%
df.groupby('Region')[['Sales','Profit']].sum().reset_index().sort_values(by='Sales',ascending=False)
# Out:
#     Region        Sales       Profit
# 3     West  724309.2935  108214.9893
# 1     East  677843.9080   91471.0909
# 0  Central  500724.2708   39662.0474
# 2    South  391721.9050   46749.4303

# %% [markdown]
# ## Observation)8
# ## west is up for sales and profits for 724309 and 108214 in that order
# ## east is 2nd for sales and profit for 677843 and 91471 in that order

# %%
sub_sales = df.groupby('Sub-Category')['Sales'].sum()
sub_profit = df.groupby('Sub-Category')['Profit'].sum()

# %%
df.groupby('Sub-Category')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
# Out:
#    Sub-Category        Sales
# 13       Phones  329704.6780
# 5        Chairs  327777.7610
# 14      Storage  223808.4400
# 16       Tables  206965.5320
# 3       Binders  203328.8590
# 11     Machines  189238.6310
# 0   Accessories  167303.3020
# 6       Copiers  149528.0300
# 4     Bookcases  114166.9293
# 1    Appliances  107532.1610
# 9   Furnishings   91658.4440
# 12        Paper   77960.8940
# 15     Supplies   46673.5380
# 2           Art   27065.7320
# 7     Envelopes   16476.4020
# 10       Labels   12385.7640
# 8     Fasteners    3024.2800

# %%
df.groupby('Sub-Category')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
# Out:
#    Sub-Category      Profit
# 6       Copiers  55617.8249
# 13       Phones  44493.0524
# 0   Accessories  41920.9052
# 12        Paper  33830.0381
# 3       Binders  30205.2603
# 5        Chairs  26567.1278
# 14      Storage  21287.1788
# 1    Appliances  18138.0054
# 9   Furnishings  13042.0534
# 7     Envelopes   6964.1767
# 2           Art   6511.8388
# 10       Labels   5499.1558
# 11     Machines   3384.7569
# 8     Fasteners    949.5182
# 15     Supplies  -1189.0995
# 4     Bookcases  -3398.7542
# 16       Tables -17725.4811

# %%
sub_sales.plot(kind='bar',legend=True)
sub_profit.plot(kind='bar',color ='crimson', legend=True)
plt.show()

# %% [markdown]
# ## Observation)9
# ## phones is up for sales and profits for 329704 and 44493 in that order
# ## Chairs is 2nd for sales and profit for 327777 and 26567 in that order
# ## Supplies,Bookcases and tables are all losing with -1189,-3398,-17725 in that order we may have to use another plan for these subs

# %%
sns.lineplot(x=df['Discount'],y=df['Profit']);

# %% [markdown]
# ## Observation)10
# ## we see high decrease in profit whenever discount increases

# %%
df.groupby('Sub-Category')[['Sales','Profit']].sum().plot.bar();

# %% [markdown]
# ## Observation)10
# ## phones and chairs are top for sales and profit while tables has a negative profit \ lossing already

# %%
df.groupby('City')[['Sales','Profit']].sum().nlargest(columns='Sales',n=10).plot.bar();

# %% [markdown]
# ## Observation)11
# ## new york city and los angeles are top for sales and profit, we are aware for phili houston chicago and jacksonville all losing

# %%
df.groupby('State')[['Sales','Profit']].sum().nlargest(columns='Sales',n=10).plot.bar();

# %% [markdown]
# ## Observation)12
# ## california and new york are top for sales and profit, we are aware for texas pensylvania florida illinois and ohio all losing

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ## Conclusion :
# ### weak areas where we can work on them to make more profits are
# ### 1. we should decrease/limit producing furniture and increase tech and office supplies as furniture has less profit
# ### 2. speaking about sub-categories producing tables should be decreased
# ### 3. west region has the most sales so we may have to produce more products there
# ### 4. we may have to limit productions in texas pensylvania florida illinois and ohio as these states are losing us money
